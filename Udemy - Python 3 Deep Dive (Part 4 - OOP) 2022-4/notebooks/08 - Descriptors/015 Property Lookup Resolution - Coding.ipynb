# %% [markdown]
# # Property Lookup Resolution - Coding

# %%
class IntegerValue:
    def __set__(self, instance, value):
        print("__set__ called...")
        
    def __get__(self, instance, owner_class):
        print("__get__ called...")
        

class Point:
    x = IntegerValue()

# %%
p = Point()
p.x = 100
print(p.x)
p.__dict__
# Out:
# __set__ called...
# __get__ called...
# None
# {}

# %%
p.__dict__["x"] = 200
p.__dict__
# Out:
# {'x': 200}

# %%
p.x
# Out:
# __get__ called...

# %%
class TimeUTC:
    def __get__(self, instance, owner_class):
        print("__get__ called...")
        
class Logger:
    current_time = TimeUTC()

# %%
l = Logger()
l.current_time
# Out:
# __get__ called...

# %%
l.__dict__["current_time"] = "hello"
l.__dict__
# Out:
# {'current_time': 'hello'}

# %%
l.current_time
# Out:
# 'hello'

# %%
del l.__dict__["current_time"]

# %%
l.current_time
# Out:
# __get__ called...

# %%
class ValidString:
    def __init__(self, min_length=None):
        self.min_length = min_length
        
    def __set_name__(self, owner_class, property_name):
        self.property_name = property_name
        
    def __set__(self, instance, value):
        if not isinstance(value, str):
            raise ValueError(f"{self.property_name} must be as String.")
        if self.min_length is not None and self.min_length < self.min_length:
            raise ValueError(f"{self.property_name} not long enough.")
        instance.__dict__[self.property_name] = value
        
    def __get__(self, instance, owner_class):
        if instance is None:
            return self
        print(f"calling __get__ for {self.property_name}")
        return instance.__dict__.get(self.property_name, None)
    
class Person:
    first_name = ValidString(1)
    last_name = ValidString(2)
    
p = Person()
p.first_name = "Alex"
p.last_name = "Mussoliny"
print(p.first_name)
print(p.last_name)
print(p.__dict__)
# Out:
# calling __get__ for first_name
# Alex
# calling __get__ for last_name
# Mussoliny
# {'first_name': 'Alex', 'last_name': 'Mussoliny'}

# %%
p.__dict__["first_name"] = "Ben"
print(p.__dict__)
print(p.first_name)
p.first_name = "Alex"
print(p.__dict__)
print(p.first_name)
# Out:
# {'first_name': 'Ben', 'last_name': 'Mussoliny'}
# calling __get__ for first_name
# Ben
# {'first_name': 'Alex', 'last_name': 'Mussoliny'}
# calling __get__ for first_name
# Alex

# %%
class ValidString:
    def __init__(self, min_length=None):
        self.min_length = min_length
        
    def __set_name__(self, owner_class, property_name):
        self.property_name = property_name
        
    def __set__(self, instance, value):
        print("__set__ called...")
        if not isinstance(value, str):
            raise ValueError(f"{self.property_name} must be as String.")
        if self.min_length is not None and self.min_length < self.min_length:
            raise ValueError(f"{self.property_name} not long enough.")
        setattr(instance, self.property_name, value)
        
    def __get__(self, instance, owner_class):
        if instance is None:
            return self
        print(f"calling __get__ for {self.property_name}")
        return getattr(instance, self.property_name, None)
    
class Person:
    first_name = ValidString(1)
    last_name = ValidString(2)
    
p = Person()
p.first_name = "Alex"
p.last_name = "Mussoliny"
print(p.first_name)
print(p.last_name)
print(p.__dict__)
# Out:
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# __set__ called...
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Input In [25], in <cell line: 27>()
#      24     last_name = ValidString(2)
#      26 p = Person()
# ---> 27 p.first_name = "Alex"
#      28 p.last_name = "Mussoliny"
#      29 print(p.first_name)
#
# Input In [25], in ValidString.__set__(self, instance, value)
#      12 if self.min_length is not None and self.min_length < self.min_length:
#      13     raise ValueError(f"{self.property_name} not long enough.")
# ---> 14 setattr(instance, self.property_name, value)
#
# Input In [25], in ValidString.__set__(self, instance, value)
#      12 if self.min_length is not None and self.min_length < self.min_length:
#      13     raise ValueError(f"{self.property_name} not long enough.")
# ---> 14 setattr(instance, self.property_name, value)
#
#     [... skipping similar frames: ValidString.__set__ at line 14 (1481 times)]
#
# Input In [25], in ValidString.__set__(self, instance, value)
#      12 if self.min_length is not None and self.min_length < self.min_length:
#      13     raise ValueError(f"{self.property_name} not long enough.")
# ---> 14 setattr(instance, self.property_name, value)
#
# Input In [25], in ValidString.__set__(self, instance, value)
#       8 def __set__(self, instance, value):
# ----> 9     print("__set__ called...")
#      10     if not isinstance(value, str):
#      11         raise ValueError(f"{self.property_name} must be as String.")
#
# File ~/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py:213, in IOPubThread.schedule(self, f)
#     208 def schedule(self, f):
#     209     """Schedule a function to be called in our IO thread.
#     210
#     211     If the thread is not running, call immediately.
#     212     """
# --> 213     if self.thread.is_alive():
#     214         self._events.append(f)
#     215         # wake event thread (message content is ignored)
#
# File ~/anaconda3/lib/python3.9/threading.py:1135, in Thread.is_alive(self)
#    1127 """Return whether the thread is alive.
#    1128
#    1129 This method returns True just before the run() method starts until just
#    (...)
#    1132
#    1133 """
#    1134 assert self._initialized, "Thread.__init__() not called"
# -> 1135 if self._is_stopped or not self._started.is_set():
#    1136     return False
#    1137 self._wait_for_tstate_lock(False)
#
# RecursionError: maximum recursion depth exceeded
